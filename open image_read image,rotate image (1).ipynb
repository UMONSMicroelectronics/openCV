# %%
from PIL import Image
import numpy as np

im = Image.open('opencv_logo.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=179x215 at 0xA5B266B0>

# %% [markdown]
# # Rotation of Image

# %%
im.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGBA size=179x215 at 0xA5B266F0>

# %%
im.rotate(125)
# Out:
# <PIL.Image.Image image mode=RGBA size=179x215 at 0xA5B26310>

# %% [markdown]
# # Task

# %% [markdown]
# 1) Roatate image 30,45,90,180,360 angle
