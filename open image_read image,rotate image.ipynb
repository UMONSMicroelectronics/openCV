# %%
from PIL import Image
import numpy as np

im = Image.open('opencv_logo.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=179x215 at 0xB02800B0>

# %% [markdown]
# # Rotation of Image

# %%
im.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGBA size=179x215 at 0xB02D7DD0>

# %%
im.rotate(125)
# Out:
# <PIL.Image.Image image mode=RGBA size=179x215 at 0xB02D7EF0>

# %% [markdown]
# # Task

# %% [markdown]
# 1) Roatate image 30,45,90,180,360 angle

# %%
imgplot = plt.imshow(img)

# %%
cv2.imwrite('opencv_logo.png',img)
# Out:
# True

# %% [markdown]
# # make a border

# %%
import cv2
import numpy as np

BLUE = [255,0,0]

img1 = cv2.imread('opencv_logo.png')

constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()
